# %% [markdown]
# <a href="https://colab.research.google.com/github/Zadak-H/Alzheimer-detection-and-classification-Using-Deep-Learning/blob/main/Alzheimer_detection_and_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Problem Definition**
#
# >*Alzheimer is known the most for the causes of dementia. It takes 2/3 of the whole dementia popilation, while the cause is still unknown. According to papers from Lancet neurology, even the old theory such as neural inflations, which was disregarded as the cause compared to tau-protein, beta-amiloids, and genetic factors (Apo E4).*
#
#
# Before I start, I'll have to explain a bit more about the Alzheimer, because, the data contains 4 classes of Alzheimer that depends on the severity of dementia.
#
# There are degrees of severity in Alzheimer.
#
# *   Very mildly demented : This is the stage where patient starts to forget where they put their stuff, other people's names recently, etc. It is hard to detect through cognitive ability test.
#
# *   Mildly demented : This is the stage where patients don't remember the words, can't find their way to the destination, loss of focus and work-abilities. This is also the stage where patients even forget that they are losing memory. From this stage, with cognitive testing, it can be found.
#
# *   Moderately demented : Starts to forget the recent activities, important old histories, have hard time calculating the budget, hard to go outside alone, and loss of empathy.
#
# There are 3 more stages in the moderately dementia, which in the terminal stage, the patient can't move on their own, while they lose the ability to speak. But I assume that the current dataset from Kaggle [https://www.kaggle.com/datasets/sachinkumar413/alzheimer-mri-dataset] is considering all the these stages merged inside 'Moderately demeted' or not even considered.
#
# Knowing these stages are important because the faster the stage the patient is at, the treatment will have higher effect in terms of slowing the process. If the dementia is found during the moderately demented stage, it is known that the patient will pass away in 3 years. (One of the reported case is a rythm guitarists Malcom from the band AC/DC was diagnosed severe dementia at 2014.)
#
# Thus, having an AI that detects alzheimer dementia in the early stage can allow longer life expactancy from the patient as well as higher life quality overall from the slowdown of dementia.
#
# As Alzheimer can not only be found with cognitive ability testing, but also through MRI or CT by looking at the ventricles of the brain and cortical atrophy, the theoratical foundation on this project is solid. Doctors find the patient with Alzheimer's have a brain that have enlarged ventricles (that lies in the center of the brain) as well as thinner cortical grey area of the brain.

# %% [markdown]
# # **2. Solution Specification**
#
#
# > *This project will go through various Deep Learning models from Convolutional Neural Network models using reLU for Detection and Classification.
# In this Project I will use GANs for Superresolution the images and then I will use GANs for Synthetic Image generation For getting more test and train images.*

# %% [markdown]
# # **Lets Start The coding Part**

# %% [markdown]
# ### *Import dataFrom Google Drive*

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
# Set Directory path for Dataset
os.chdir("/content/gdrive/MyDrive/Project_folder/")
root_path = "/content/gdrive/MyDrive/Project_folder/"
Dataset='Dataset'
Data_Dir=os.listdir(Dataset)
print(Data_Dir)
# Out:
# ['Non_Demented', 'Moderate_Demented', 'Very_Mild_Demented', 'Mild_Demented']

# %%
list = os.listdir("Dataset/Non_Demented/") # dir is your directory path
Non_Demented = len(list)
print("Non_Demented -> " + str(Non_Demented))

list = os.listdir("Dataset/Moderate_Demented/") # dir is your directory path
Moderate_Demented = len(list)
print("Moderate_Demented -> " + str(Moderate_Demented))

list = os.listdir("Dataset/Very_Mild_Demented/") # dir is your directory path
Very_Mild_Demented = len(list)
print("Very_Mild_Demented -> " + str(Very_Mild_Demented))

list = os.listdir("Dataset/Mild_Demented/") # dir is your directory path
Mild_Demented = len(list)
print("Mild_Demented -> " + str(Mild_Demented))
# Out:
# Non_Demented -> 3200
# Moderate_Demented -> 64
# Very_Mild_Demented -> 2240
# Mild_Demented -> 1352

# %% [markdown]
# # **Import Libaries**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
from tensorflow import keras
from keras import layers
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# ## *Dataset Load*

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('./Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))

# %% [markdown]
# ### Data Preprocessing

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 7095 files belonging to 4 classes.
# Found 1274 files belonging to 4 classes.
# Found 1276 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [Mild_Demented, Moderate_Demented, Non_Demented, Very_Mild_Demented]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # **Model - CNN**

# %%
model = keras.models.Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64,"relu"))
model.add(keras.layers.Dense(4,"softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "Adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 128, 128, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten_2 (Flatten)         (None, 16384)             0
#
#  dense_7 (Dense)             (None, 128)               2097280
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dense_9 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,129,380
# Trainable params: 2,129,380
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### *Plot Model*

# %%
# Plot the model
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='Alzheimer_detection_architecture.png')

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 11s 118ms/step - loss: 1.2674 - accuracy: 0.4698 - val_loss: 1.0883 - val_accuracy: 0.6009
# Epoch 2/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.9506 - accuracy: 0.5403 - val_loss: 1.0209 - val_accuracy: 0.5524
# Epoch 3/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.8788 - accuracy: 0.5757 - val_loss: 0.8946 - val_accuracy: 0.6338
# Epoch 4/100
# 80/80 [==============================] - 10s 121ms/step - loss: 0.8180 - accuracy: 0.6370 - val_loss: 0.8215 - val_accuracy: 0.6729
# Epoch 5/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.7567 - accuracy: 0.6536 - val_loss: 0.6964 - val_accuracy: 0.7449
# Epoch 6/100
# 80/80 [==============================] - 11s 123ms/step - loss: 0.6824 - accuracy: 0.7042 - val_loss: 0.5981 - val_accuracy: 0.7700
# Epoch 7/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.5888 - accuracy: 0.7392 - val_loss: 0.5636 - val_accuracy: 0.7637
# Epoch 8/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.4994 - accuracy: 0.7857 - val_loss: 0.4630 - val_accuracy: 0.8247
# Epoch 9/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.4405 - accuracy: 0.8101 - val_loss: 0.3589 - val_accuracy: 0.8795
# Epoch 10/100
# 80/80 [==============================] - 10s 122ms/step - loss: 0.3208 - accuracy: 0.8715 - val_loss: 0.2529 - val_accuracy: 0.9296
# Epoch 11/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.2761 - accuracy: 0.8924 - val_loss: 0.2194 - val_accuracy: 0.9343
# Epoch 12/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.2471 - accuracy: 0.9064 - val_loss: 0.1881 - val_accuracy: 0.9437
# Epoch 13/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.1979 - accuracy: 0.9267 - val_loss: 0.1573 - val_accuracy: 0.9577
# Epoch 14/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.1450 - accuracy: 0.9473 - val_loss: 0.1200 - val_accuracy: 0.9624
# Epoch 15/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.1503 - accuracy: 0.9404 - val_loss: 0.1673 - val_accuracy: 0.9405
# Epoch 16/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.1173 - accuracy: 0.9574 - val_loss: 0.1069 - val_accuracy: 0.9656
# Epoch 17/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0898 - accuracy: 0.9685 - val_loss: 0.1263 - val_accuracy: 0.9515
# Epoch 18/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0688 - accuracy: 0.9768 - val_loss: 0.0676 - val_accuracy: 0.9734
# Epoch 19/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0816 - accuracy: 0.9697 - val_loss: 0.0813 - val_accuracy: 0.9656
# Epoch 20/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0691 - accuracy: 0.9756 - val_loss: 0.0421 - val_accuracy: 0.9890
# Epoch 21/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0704 - accuracy: 0.9740 - val_loss: 0.0600 - val_accuracy: 0.9750
# Epoch 22/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0566 - accuracy: 0.9803 - val_loss: 0.0541 - val_accuracy: 0.9812
# Epoch 23/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0486 - accuracy: 0.9832 - val_loss: 0.0717 - val_accuracy: 0.9734
# Epoch 24/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0468 - accuracy: 0.9834 - val_loss: 0.0351 - val_accuracy: 0.9890
# Epoch 25/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0387 - accuracy: 0.9869 - val_loss: 0.0511 - val_accuracy: 0.9844
# Epoch 26/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0411 - accuracy: 0.9853 - val_loss: 0.0506 - val_accuracy: 0.9875
# Epoch 27/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0402 - accuracy: 0.9869 - val_loss: 0.0439 - val_accuracy: 0.9828
# Epoch 28/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0201 - accuracy: 0.9941 - val_loss: 0.0561 - val_accuracy: 0.9828
# Epoch 29/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0308 - accuracy: 0.9904 - val_loss: 0.0389 - val_accuracy: 0.9828
# Epoch 30/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.0512 - val_accuracy: 0.9765
# Epoch 31/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.0407 - val_accuracy: 0.9828
# Epoch 32/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0407 - val_accuracy: 0.9859
# Epoch 33/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0290 - accuracy: 0.9893 - val_loss: 0.0424 - val_accuracy: 0.9828
# Epoch 34/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0343 - val_accuracy: 0.9890
# Epoch 35/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0321 - accuracy: 0.9885 - val_loss: 0.0266 - val_accuracy: 0.9937
# Epoch 36/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0212 - accuracy: 0.9930 - val_loss: 0.0256 - val_accuracy: 0.9922
# Epoch 37/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 0.0355 - val_accuracy: 0.9844
# Epoch 38/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 0.0366 - val_accuracy: 0.9875
# Epoch 39/100
# 80/80 [==============================] - 10s 121ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0207 - val_accuracy: 0.9906
# Epoch 40/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.0153 - val_accuracy: 0.9953
# Epoch 41/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0363 - val_accuracy: 0.9844
# Epoch 42/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0108 - accuracy: 0.9975 - val_loss: 0.0234 - val_accuracy: 0.9890
# Epoch 43/100
# 80/80 [==============================] - 10s 120ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0171 - val_accuracy: 0.9953
# Epoch 44/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.0288 - val_accuracy: 0.9890
# Epoch 45/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0251 - accuracy: 0.9910 - val_loss: 0.0468 - val_accuracy: 0.9812
# Epoch 46/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0189 - accuracy: 0.9932 - val_loss: 0.0268 - val_accuracy: 0.9937
# Epoch 47/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.0402 - val_accuracy: 0.9859
# Epoch 48/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0226 - val_accuracy: 0.9906
# Epoch 49/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0282 - accuracy: 0.9904 - val_loss: 0.0420 - val_accuracy: 0.9875
# Epoch 50/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0227 - accuracy: 0.9908 - val_loss: 0.0265 - val_accuracy: 0.9922
# Epoch 51/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.0214 - val_accuracy: 0.9890
# Epoch 52/100
# 80/80 [==============================] - 10s 121ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 53/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0211 - val_accuracy: 0.9937
# Epoch 54/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0050 - val_accuracy: 0.9984
# Epoch 55/100
# 80/80 [==============================] - 10s 120ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.0292 - val_accuracy: 0.9937
# Epoch 56/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0136 - val_accuracy: 0.9969
# Epoch 57/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0163 - accuracy: 0.9928 - val_loss: 0.0171 - val_accuracy: 0.9922
# Epoch 58/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0168 - accuracy: 0.9928 - val_loss: 0.0319 - val_accuracy: 0.9875
# Epoch 59/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0398 - accuracy: 0.9885 - val_loss: 0.0182 - val_accuracy: 0.9922
# Epoch 60/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 0.0223 - val_accuracy: 0.9890
# Epoch 61/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0116 - accuracy: 0.9965 - val_loss: 0.0107 - val_accuracy: 0.9937
# Epoch 62/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0113 - accuracy: 0.9957 - val_loss: 0.0116 - val_accuracy: 0.9953
# Epoch 63/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0112 - accuracy: 0.9961 - val_loss: 0.0539 - val_accuracy: 0.9828
# Epoch 64/100
# 80/80 [==============================] - 10s 118ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0129 - val_accuracy: 0.9922
# Epoch 65/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0213 - accuracy: 0.9928 - val_loss: 0.0101 - val_accuracy: 0.9937
# Epoch 66/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0166 - accuracy: 0.9934 - val_loss: 0.0386 - val_accuracy: 0.9844
# Epoch 67/100
# 80/80 [==============================] - 10s 120ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.0120 - val_accuracy: 0.9953
# Epoch 68/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.0212 - val_accuracy: 0.9906
# Epoch 69/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0203 - accuracy: 0.9939 - val_loss: 0.0180 - val_accuracy: 0.9937
# Epoch 70/100
# 80/80 [==============================] - 10s 120ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0174 - val_accuracy: 0.9953
# Epoch 71/100
# 80/80 [==============================] - 10s 114ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0556 - val_accuracy: 0.9812
# Epoch 72/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0178 - accuracy: 0.9951 - val_loss: 0.0282 - val_accuracy: 0.9890
# Epoch 73/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 0.0524 - val_accuracy: 0.9859
# Epoch 74/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0180 - accuracy: 0.9934 - val_loss: 0.0396 - val_accuracy: 0.9906
# Epoch 75/100
# 80/80 [==============================] - 10s 114ms/step - loss: 0.0158 - accuracy: 0.9943 - val_loss: 0.0131 - val_accuracy: 0.9953
# Epoch 76/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0217 - accuracy: 0.9922 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 77/100
# 80/80 [==============================] - 10s 114ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.0139 - val_accuracy: 0.9953
# Epoch 78/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0296 - val_accuracy: 0.9906
# Epoch 79/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0115 - accuracy: 0.9971 - val_loss: 0.0280 - val_accuracy: 0.9890
# Epoch 80/100
# 80/80 [==============================] - 10s 113ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0048 - val_accuracy: 0.9984
# Epoch 81/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0028 - accuracy: 0.9986 - val_loss: 0.0071 - val_accuracy: 0.9969
# Epoch 82/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0169 - accuracy: 0.9943 - val_loss: 0.0114 - val_accuracy: 0.9969
# Epoch 83/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0063 - accuracy: 0.9971 - val_loss: 0.0113 - val_accuracy: 0.9953
# Epoch 84/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0102 - val_accuracy: 0.9984
# Epoch 85/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 0.0411 - val_accuracy: 0.9844
# Epoch 86/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.0136 - val_accuracy: 0.9969
# Epoch 87/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0416 - accuracy: 0.9875 - val_loss: 0.0211 - val_accuracy: 0.9906
# Epoch 88/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 89/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0158 - val_accuracy: 0.9937
# Epoch 90/100
# 80/80 [==============================] - 10s 119ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0279 - val_accuracy: 0.9922
# Epoch 91/100
# 80/80 [==============================] - 10s 120ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0083 - val_accuracy: 0.9969
# Epoch 92/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0118 - accuracy: 0.9955 - val_loss: 0.0110 - val_accuracy: 0.9953
# Epoch 93/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.0089 - val_accuracy: 0.9969
# Epoch 94/100
# 80/80 [==============================] - 10s 113ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.0111 - val_accuracy: 0.9922
# Epoch 95/100
# 80/80 [==============================] - 10s 112ms/step - loss: 0.0045 - accuracy: 0.9992 - val_loss: 0.0152 - val_accuracy: 0.9937
# Epoch 96/100
# 80/80 [==============================] - 10s 113ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 97/100
# 80/80 [==============================] - 10s 116ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0116 - val_accuracy: 0.9984
# Epoch 98/100
# 80/80 [==============================] - 10s 111ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0136 - val_accuracy: 0.9937
# Epoch 99/100
# 80/80 [==============================] - 10s 117ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0129 - val_accuracy: 0.9953
# Epoch 100/100
# 80/80 [==============================] - 10s 115ms/step - loss: 0.0172 - accuracy: 0.9959 - val_loss: 0.0308 - val_accuracy: 0.9890

# %% [markdown]
# ## **Plot results**

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']

# %%
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# # **Prediction**

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 1s 32ms/step - loss: 0.0278 - accuracy: 0.9922

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})
            
        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
